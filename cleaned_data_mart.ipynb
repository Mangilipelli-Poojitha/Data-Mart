# %% [markdown]
# #DATA CLEANING

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive')
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import math

# %%
df=pd.read_csv("data_mart.csv")
df
# Out:
#       week_date   region platform segment customer_type  transactions  \
# 0     8/31/2020     ASIA   Retail      C3           New        120631
# 1     8/31/2020     ASIA   Retail      F1           New         31574
# 2     8/31/2020      USA   Retail     NaN         Guest        529151
# 3     8/31/2020   EUROPE   Retail      C1           New          4517
# 4     8/31/2020   AFRICA   Retail      C2           New         58046
# ...         ...      ...      ...     ...           ...           ...
# 8949   6/3/2019   AFRICA   Retail      C4           New         41300
# 8950   6/3/2019  OCEANIA   Retail      C1      Existing        224382
# 8951   6/3/2019   EUROPE  Shopify      C1      Existing            94
# 8952   6/3/2019   AFRICA  Shopify      C2           New           304
# 8953   6/3/2019   EUROPE   Retail      C3           New          4019
#
#          sales
# 0      3656163
# 1       996575
# 2     16509610
# 3       141942
# 4      1758388
# ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# week_date           0
# region              0
# platform            0
# segment          1581
# customer_type       0
# transactions        0
# sales               0
# dtype: int64

# %%
df['segment']=df['segment'].fillna('unknown')

# %%
df.isnull().sum()
# Out:
# week_date        0
# region           0
# platform         0
# segment          0
# customer_type    0
# transactions     0
# sales            0
# dtype: int64

# %%
df.dtypes
# Out:
# week_date        object
# region           object
# platform         object
# segment          object
# customer_type    object
# transactions      int64
# sales             int64
# dtype: object

# %%
df['Date']=pd.to_datetime(df.week_date)

# %%
df.head()
# Out:
#    week_date  region platform  segment customer_type  transactions     sales  \
# 0  8/31/2020    ASIA   Retail       C3           New        120631   3656163
# 1  8/31/2020    ASIA   Retail       F1           New         31574    996575
# 2  8/31/2020     USA   Retail  unknown         Guest        529151  16509610
# 3  8/31/2020  EUROPE   Retail       C1           New          4517    141942
# 4  8/31/2020  AFRICA   Retail       C2           New         58046   1758388
#
#         Date
# 0 2020-08-31
# 1 2020-08-31
# 2 2020-08-31
# 3 2020-08-31
# 4 2020-08-31

# %%
df['Day']=df["Date"].dt.day

# %%
def calculate_week_number(day):
  if day>=1 and day<=7:
    return 1
  elif day>=8 and day<=14:
    return 2
  elif day>=15 and day<=21:
    return 3
  elif day >=22 and day<=28:
    return 4
  else:
    return 5


df['week_number'] = df['Day'].apply(calculate_week_number)

# %%
df.head()
# Out:
#    week_date  region platform  segment customer_type  transactions     sales  \
# 0  8/31/2020    ASIA   Retail       C3           New        120631   3656163
# 1  8/31/2020    ASIA   Retail       F1           New         31574    996575
# 2  8/31/2020     USA   Retail  unknown         Guest        529151  16509610
# 3  8/31/2020  EUROPE   Retail       C1           New          4517    141942
# 4  8/31/2020  AFRICA   Retail       C2           New         58046   1758388
#
#         Date  Day  week_number
# 0 2020-08-31   31            5
# 1 2020-08-31   31            5
# 2 2020-08-31   31            5
# 3 2020-08-31   31            5
# 4 2020-08-31   31            5

# %%
df['month_number']=df['Date'].dt.month
df['calendar_year']=df['Date'].dt.year
df.tail()
# Out:
#      week_date   region platform segment customer_type  transactions    sales  \
# 8949  6/3/2019   AFRICA   Retail      C4           New         41300  1435531
# 8950  6/3/2019  OCEANIA   Retail      C1      Existing        224382  8490293
# 8951  6/3/2019   EUROPE  Shopify      C1      Existing            94    18830
# 8952  6/3/2019   AFRICA  Shopify      C2           New           304    43518
# 8953  6/3/2019   EUROPE   Retail      C3           New          4019   175896
#
#            Date  Day  week_number  month_number  calendar_year
# 8949 2019-06-03    3            1             6           2019
# 8950 2019-06-03    3            1             6           2019
# 8951 2019-06-03    3            1             6           2019
# 8952 2019-06-03    3            1             6           2019
# 8953 2019-06-03    3            1             6           2019

# %%
df['month_name']=df['Date'].dt.strftime('%b')
df
# Out:
#       week_date   region platform  segment customer_type  transactions  \
# 0     8/31/2020     ASIA   Retail       C3           New        120631
# 1     8/31/2020     ASIA   Retail       F1           New         31574
# 2     8/31/2020      USA   Retail  unknown         Guest        529151
# 3     8/31/2020   EUROPE   Retail       C1           New          4517
# 4     8/31/2020   AFRICA   Retail       C2           New         58046
# ...         ...      ...      ...      ...           ...           ...
# 8949   6/3/2019   AFRICA   Retail       C4           New         41300
# 8950   6/3/2019  OCEANIA   Retail       C1      Existing        224382
# 8951   6/3/2019   EUROPE  Shopify       C1      Existing            94
# 8952   6/3/2019   AFRICA  Shopify       C2           New           304
# 8953   6/3/2019   EUROPE   Retail       C3           New          4019
#
#          sales       Date  Day  week_number  month_number  calendar_year  \
# ...

# %%
def map_demographic(s):
  s=str(s)
  if s[0]=='C':
    return 'Couples'
  elif s[0]=='F':
    return 'Families'
  else:
    return 'unknown'



df['demographic'] = df['segment'].apply(map_demographic)

# %%
df.head()
# Out:
#    week_date  region platform  segment customer_type  transactions     sales  \
# 0  8/31/2020    ASIA   Retail       C3           New        120631   3656163
# 1  8/31/2020    ASIA   Retail       F1           New         31574    996575
# 2  8/31/2020     USA   Retail  unknown         Guest        529151  16509610
# 3  8/31/2020  EUROPE   Retail       C1           New          4517    141942
# 4  8/31/2020  AFRICA   Retail       C2           New         58046   1758388
#
#         Date  Day  week_number  month_number  calendar_year month_name  \
# 0 2020-08-31   31            5             8           2020        Aug
# 1 2020-08-31   31            5             8           2020        Aug
# 2 2020-08-31   31            5             8           2020        Aug
# 3 2020-08-31   31            5             8           2020        Aug
# 4 2020-08-31   31            5             8           2020        Aug
#
#   demographic
# 0     Couples
# 1    Families
# 2     unknown
# ...

# %%
def map_age_band(s):
  s=str(s)
  if s[1]=='1':
    return 'Young Adults'
  elif s[1]=='2':
    return 'Middle Aged'
  elif s[1]=='3' or s[1]=='4':
    return 'Retirees'
  else:
    return 'unknown'


df['age_band']=df['segment'].apply(map_age_band)

# %%
df.head()
# Out:
#    week_date  region platform  segment customer_type  transactions     sales  \
# 0  8/31/2020    ASIA   Retail       C3           New        120631   3656163
# 1  8/31/2020    ASIA   Retail       F1           New         31574    996575
# 2  8/31/2020     USA   Retail  unknown         Guest        529151  16509610
# 3  8/31/2020  EUROPE   Retail       C1           New          4517    141942
# 4  8/31/2020  AFRICA   Retail       C2           New         58046   1758388
#
#         Date  Day  week_number  month_number  calendar_year month_name  \
# 0 2020-08-31   31            5             8           2020        Aug
# 1 2020-08-31   31            5             8           2020        Aug
# 2 2020-08-31   31            5             8           2020        Aug
# 3 2020-08-31   31            5             8           2020        Aug
# 4 2020-08-31   31            5             8           2020        Aug
#
#   demographic      age_band
# 0     Couples      Retirees
# ...

# %%
df['avg_transaction']=round(df['sales']/df['transactions'],2)
df
# Out:
#       week_date   region platform  segment customer_type  transactions  \
# 0     8/31/2020     ASIA   Retail       C3           New        120631
# 1     8/31/2020     ASIA   Retail       F1           New         31574
# 2     8/31/2020      USA   Retail  unknown         Guest        529151
# 3     8/31/2020   EUROPE   Retail       C1           New          4517
# 4     8/31/2020   AFRICA   Retail       C2           New         58046
# ...         ...      ...      ...      ...           ...           ...
# 8949   6/3/2019   AFRICA   Retail       C4           New         41300
# 8950   6/3/2019  OCEANIA   Retail       C1      Existing        224382
# 8951   6/3/2019   EUROPE  Shopify       C1      Existing            94
# 8952   6/3/2019   AFRICA  Shopify       C2           New           304
# 8953   6/3/2019   EUROPE   Retail       C3           New          4019
#
#          sales       Date  Day  week_number  month_number  calendar_year  \
# ...

# %%
df.to_csv('cleaned_data_mart.csv',index=False)

# %% [markdown]
# cleaned dataframe is saved back as cleaned_data_mart
